# %%
import pandas as pd

files_name = ['agency', 'calendar_dates', 'calendar', 'routes', 'trips', 'shapes', 'stops', 'stop_times']



for i in range(len(files_name)):
    df = pd.read_csv(f"{files_name[i]}.txt")
    print(f"lentgh of {files_name[i]} is: {len(df)}")
    df.to_csv(f"{files_name[i]}.csv", index=False)
# Out:
# lentgh of agency is: 1
# lentgh of calendar_dates is: 6
# lentgh of calendar is: 4
# lentgh of routes is: 228
# lentgh of trips is: 126273
# lentgh of shapes is: 948507
# lentgh of stops is: 9096
# lentgh of stop_times is: 4041966
